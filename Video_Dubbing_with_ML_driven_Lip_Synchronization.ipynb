# %%
# %pip install pydub
# %pip install ffmpeg-python
# %pip install mediapipe==0.10.11
# Out:
# Requirement already satisfied: pydub in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (0.25.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ip (c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages)
# Requirement already satisfied: ffmpeg-python in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (0.2.0)
# Requirement already satisfied: future in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from ffmpeg-python) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ip (c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages)
# Requirement already satisfied: mediapipe==0.10.11 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (0.10.11)
# Requirement already satisfied: absl-py in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from mediapipe==0.10.11) (2.2.2)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from mediapipe==0.10.11) (25.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from mediapipe==0.10.11) (25.2.10)
# Requirement already satisfied: jax in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from mediapipe==0.10.11) (0.4.13)
# Requirement already satisfied: matplotlib in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from mediapipe==0.10.11) (3.7.5)
# Requirement already satisfied: numpy in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from mediapipe==0.10.11) (1.24.3)
# Requirement already satisfied: opencv-contrib-python in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from mediapipe==0.10.11) (4.11.0.86)
# Requirement already satisfied: protobuf<4,>=3.11 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from mediapipe==0.10.11) (3.20.3)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from mediapipe==0.10.11) (0.5.1)
# Requirement already satisfied: CFFI>=1.0 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from sounddevice>=0.4.4->mediapipe==0.10.11) (1.17.1)
# Requirement already satisfied: ml-dtypes>=0.1.0 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from jax->mediapipe==0.10.11) (0.2.0)
# Requirement already satisfied: opt-einsum in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from jax->mediapipe==0.10.11) (3.4.0)
# Requirement already satisfied: scipy>=1.7 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from jax->mediapipe==0.10.11) (1.10.1)
# Requirement already satisfied: importlib-metadata>=4.6 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from jax->mediapipe==0.10.11) (8.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->mediapipe==0.10.11) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->mediapipe==0.10.11) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->mediapipe==0.10.11) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->mediapipe==0.10.11) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->mediapipe==0.10.11) (25.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->mediapipe==0.10.11) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->mediapipe==0.10.11) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->mediapipe==0.10.11) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->mediapipe==0.10.11) (6.4.5)
# Requirement already satisfied: pycparser in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe==0.10.11) (2.22)
# Requirement already satisfied: zipp>=3.20 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from importlib-metadata>=4.6->jax->mediapipe==0.10.11) (3.20.2)
# Requirement already satisfied: six>=1.5 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe==0.10.11) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ip (c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages)

# %%
# %pip install https://raw.githubusercontent.com/AwaleSajil/ghc/master/ghc-1.0-py3-none-any.whl
# Out:
# Collecting ghc==1.0
#   Using cached https://raw.githubusercontent.com/AwaleSajil/ghc/master/ghc-1.0-py3-none-any.whl (13 kB)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ip (c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages)

# %%
# %pip install git+https://github.com/elliottzheng/batch-face.git@master
# Out:
# Collecting git+https://github.com/elliottzheng/batch-face.git@master
#   Cloning https://github.com/elliottzheng/batch-face.git (to revision master) to c:\users\ahmed\appdata\local\temp\pip-req-build-t4n59d0e
#   Resolved https://github.com/elliottzheng/batch-face.git to commit cc7dbf09ebc51948d152ffbda6bbac7d6daf160e
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from batch-face==1.5.1) (1.24.3)
# Requirement already satisfied: torch in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from batch-face==1.5.1) (2.4.1)
# Requirement already satisfied: torchvision in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from batch-face==1.5.1) (0.19.1)
# Requirement already satisfied: opencv-python in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from batch-face==1.5.1) (4.11.0.86)
# Requirement already satisfied: opencv_transforms in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from batch-face==1.5.1) (0.0.6)
# Requirement already satisfied: sixdrepnet in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from batch-face==1.5.1) (0.1.6)
# Requirement already satisfied: Pillow>=8.4.0 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from sixdrepnet->batch-face==1.5.1) (10.4.0)
# Requirement already satisfied: matplotlib>=3.3.4 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from sixdrepnet->batch-face==1.5.1) (3.7.5)
# Requirement already satisfied: pandas>=1.1.5 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from sixdrepnet->batch-face==1.5.1) (2.0.3)
# Requirement already satisfied: scipy>=1.5.4 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from sixdrepnet->batch-face==1.5.1) (1.10.1)
# Requirement already satisfied: filelock in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from torch->batch-face==1.5.1) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from torch->batch-face==1.5.1) (4.13.2)
# Requirement already satisfied: sympy in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from torch->batch-face==1.5.1) (1.13.3)
# Requirement already satisfied: networkx in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from torch->batch-face==1.5.1) (3.1)
# Requirement already satisfied: jinja2 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from torch->batch-face==1.5.1) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from torch->batch-face==1.5.1) (2025.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=3.3.4->sixdrepnet->batch-face==1.5.1) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=3.3.4->sixdrepnet->batch-face==1.5.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=3.3.4->sixdrepnet->batch-face==1.5.1) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=3.3.4->sixdrepnet->batch-face==1.5.1) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=3.3.4->sixdrepnet->batch-face==1.5.1) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=3.3.4->sixdrepnet->batch-face==1.5.1) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=3.3.4->sixdrepnet->batch-face==1.5.1) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=3.3.4->sixdrepnet->batch-face==1.5.1) (6.4.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from pandas>=1.1.5->sixdrepnet->batch-face==1.5.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from pandas>=1.1.5->sixdrepnet->batch-face==1.5.1) (2025.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from jinja2->torch->batch-face==1.5.1) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from sympy->torch->batch-face==1.5.1) (1.3.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=3.3.4->sixdrepnet->batch-face==1.5.1) (3.20.2)
# Requirement already satisfied: six>=1.5 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.4->sixdrepnet->batch-face==1.5.1) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ip (c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages)
#   Running command git clone --filter=blob:none --quiet https://github.com/elliottzheng/batch-face.git 'C:\Users\ahmed\AppData\Local\Temp\pip-req-build-t4n59d0e'
# WARNING: Ignoring invalid distribution -ip (c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages)

# %%
# %pip install accelerate -q
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ip (c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages)

# %%
# %pip install gdown
# Out:
# Requirement already satisfied: gdown in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from gdown) (4.13.4)
# Requirement already satisfied: filelock in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from gdown) (3.16.1)
# Requirement already satisfied: requests[socks] in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from beautifulsoup4->gdown) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from beautifulsoup4->gdown) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from requests[socks]->gdown) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from requests[socks]->gdown) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from requests[socks]->gdown) (2025.4.26)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: colorama in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from tqdm->gdown) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ip (c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages)

# %%
# %pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (8.1.6)
# Requirement already satisfied: comm>=0.1.3 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from ipywidgets) (8.12.3)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from ipywidgets) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.14 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from ipywidgets) (3.0.14)
# Requirement already satisfied: backcall in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from ipython>=6.1.0->ipywidgets) (4.4.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: pickleshare in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.19.1)
# Requirement already satisfied: stack-data in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: typing-extensions in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from ipython>=6.1.0->ipywidgets) (4.13.2)
# Requirement already satisfied: colorama in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ip (c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages)

# %%
import os

# Define the directory
video_directory = r'C:\Users\ahmed\Desktop\Zubair\Video_Dubbing_with_ML_driven_Lip_Synchronization\Test_samples'

# Check if the folder exists
if not os.path.exists(video_directory):
    print(f"❌ The folder {video_directory} does not exist!")
else:
    print(f"✅ The folder {video_directory} exists!")
# Out:
# ✅ The folder C:\Users\ahmed\Desktop\Zubair\Video_Dubbing_with_ML_driven_Lip_Synchronization\Test_samples exists!

# %%
import os
import ipywidgets as widgets
from IPython.display import display, Video, clear_output
from functools import partial

# Define the directory containing your video files
video_directory = r'C:\Users\ahmed\Desktop\Zubair\Video_Dubbing_with_ML_driven_Lip_Synchronization\Test_samples'

# Get a list of supported video files in the directory
video_files = [f for f in os.listdir(video_directory) if f.lower().endswith(('.mp4', '.mov', '.avi', '.mkv'))]

# Create a dictionary to store full video paths
video_paths = {f: os.path.join(video_directory, f) for f in video_files}

# Define max buttons per row
max_buttons_per_row = 3
button_widgets = []

# Function to handle button click
def on_button_click(video_file, b):
    global selected_video
    selected_video = video_paths[video_file]
    clear_output(wait=True)  # Clear previous output
    display(widgets.VBox(rows))  # Re-display buttons (if needed)
    print(f"✅ Selected video path: {selected_video}")
    display(Video(selected_video, embed=True, width=640, height=360))  # Inline video display

# Create a button for each video file
for video_file in video_files:
    button = widgets.Button(description=video_file[:-4])  # Remove file extension from label
    button.on_click(partial(on_button_click, video_file))
    button_widgets.append(button)

# Organize buttons into rows
rows = [widgets.HBox(button_widgets[i:i + max_buttons_per_row]) for i in range(0, len(button_widgets), max_buttons_per_row)]

# Display all video selection buttons
display(widgets.VBox(rows))
# Out:
# VBox(children=(HBox(children=(Button(description='charlie0', style=ButtonStyle()), Button(description='charlie…

# %%
# Run this code to see the selected video

# Display the selected video path to confirm
print(selected_video)

# If you want to display the video inline
from IPython.display import Video

# Display the video using the IPython display function
display(Video(selected_video, embed=True, width=640, height=360))
# Out:
# C:\Users\ahmed\Desktop\Zubair\Video_Dubbing_with_ML_driven_Lip_Synchronization\Test_samples\Oppenheimer_2.mp4
# <video controls  width="640"  height="360">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# %pip install moviepy ipython
# Out:
# Requirement already satisfied: moviepy in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (1.0.3)
# Requirement already satisfied: ipython in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (8.12.3)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from moviepy) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from moviepy) (4.67.1)
# Requirement already satisfied: requests<3.0,>=2.8.1 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from moviepy) (2.32.3)
# Requirement already satisfied: proglog<=1.0.0 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from moviepy) (0.1.11)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from moviepy) (1.24.3)
# Requirement already satisfied: imageio<3.0,>=2.5 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from moviepy) (2.35.1)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from moviepy) (0.5.1)
# Requirement already satisfied: backcall in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from ipython) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from ipython) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from ipython) (0.1.7)
# Requirement already satisfied: pickleshare in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from ipython) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from ipython) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from ipython) (2.19.1)
# Requirement already satisfied: stack-data in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from ipython) (0.6.3)
# Requirement already satisfied: traitlets>=5 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from ipython) (5.14.3)
# Requirement already satisfied: typing-extensions in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from ipython) (4.13.2)
# Requirement already satisfied: colorama in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from ipython) (0.4.6)
# Requirement already satisfied: pillow>=8.3.2 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from imageio<3.0,>=2.5->moviepy) (10.4.0)
# Requirement already satisfied: setuptools in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from imageio-ffmpeg>=0.2.0->moviepy) (41.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from jedi>=0.16->ipython) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (2025.4.26)
# Requirement already satisfied: executing>=1.2.0 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from stack-data->ipython) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from stack-data->ipython) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages (from stack-data->ipython) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ip (c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\ahmed\appdata\local\programs\python\python38\lib\site-packages)

# %%
import os
import warnings
from moviepy.editor import VideoFileClip
from IPython.display import Audio, Video, display
from tkinter import Tk, filedialog
import subprocess

warnings.filterwarnings("ignore")

# 1. File Picker for Windows (works in Jupyter on local)
def select_video_file():
    root = Tk()
    root.withdraw()  # Hide the root window
    file_path = filedialog.askopenfilename(title="Select a video file", filetypes=[("MP4 files", "*.mp4")])
    root.destroy()
    return file_path

# 2. Function to extract audio and muted video
def extract_audio_and_muted_video(input_file):
    # Load the video file
    video_clip = VideoFileClip(input_file)

    # Separate video into muted video and audio
    muted_video = video_clip.set_audio(None)
    audio_clip = video_clip.audio

    # Extract filename without extension
    filename_no_extension = os.path.splitext(os.path.basename(input_file))[0]

    # Create output folder
    output_dir = "Step1_output"
    if os.path.exists(output_dir):
        import shutil
        shutil.rmtree(output_dir)
    os.makedirs(output_dir)

    # Save muted video
    muted_video_path = os.path.join(output_dir, f"muted_{filename_no_extension}.mp4")
    muted_video.write_videofile(muted_video_path, verbose=False)

    # Save audio
    audio_path = os.path.join(output_dir, f"audio_{filename_no_extension}.wav")
    audio_clip.write_audiofile(audio_path, verbose=False)

    return muted_video_path, audio_path

# 3. Convert audio to mono, 22500 Hz using ffmpeg
def convert_to_mono(input_audio_path):
    output_audio_path = os.path.join("Step1_output", "mono_audio.wav")
    cmd = [
        "ffmpeg",
        "-y",
        "-i", input_audio_path,
        "-ac", "1",
        "-ar", "22500",
        output_audio_path
    ]
    subprocess.run(cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    return output_audio_path

# 4. Main Logic
video_path = select_video_file()
if not video_path:
    print("❌ No file selected.")
else:
    print(f"📁 Selected file: {video_path}")
    muted_path, audio_path = extract_audio_and_muted_video(video_path)
    print("✅ Extracted audio and muted video.")

    mono_audio_path = convert_to_mono(audio_path)
    print("✅ Converted to mono audio at 22500 Hz.")
    print("🎧 Playing audio preview:")
    display(Audio(filename=mono_audio_path))

# %%
#@title <h5>  Run the code to listen the extracted audio
print(extracted_audio_path)
Audio(extracted_audio_path, autoplay = True)

# %%
#@title <h3>Step3: Generate the text from the extracted audio i.e. Speech-To-Text</h1>

# %%capture
"""
Prerequisites:
tensorflow

How to use this file
1. Call speech_to_text(model_filepath, wav_filepath) function

"""

warnings.filterwarnings("ignore")

frame_length = 256
frame_step = 160

ch = [x for x in "abcdefghijklmnopqrstuvwxyz'?! "]
stoi = keras.layers.StringLookup(vocabulary=ch, oov_token="")
itos = keras.layers.StringLookup(vocabulary=stoi.get_vocabulary() , oov_token="", invert=True)

# Function required by models
@keras.saving.register_keras_serializable()
def CTC_loss(y_true, y_pred):
    batch_len = tf.cast(tf.shape(y_true)[0], dtype="int64")
    input_length = tf.cast(tf.shape(y_pred)[1], dtype="int64")
    label_length = tf.cast(tf.shape(y_true)[1], dtype="int64")

    input_length = input_length * tf.ones(shape=(batch_len, 1), dtype="int64")
    label_length = label_length * tf.ones(shape=(batch_len, 1), dtype="int64")

    loss = tf.keras.backend.ctc_batch_cost(y_true, y_pred, input_length, label_length)
    return loss

# Encode and decode functions
def encodeSample(wavFile):
    wav = tf.io.read_file(wavFile)
    wav, _ = tf.audio.decode_wav(wav)
    wav = tf.squeeze(wav, axis=-1)
    audio = tf.cast(wav, tf.float32)
    spectogram = tf.signal.stft(audio, frame_length=frame_length, frame_step=frame_step)
    spectogram = tf.abs(spectogram)
    spectogram = tf.math.pow(spectogram, 0.5)
    means = tf.math.reduce_mean(spectogram, 1, keepdims=True)
    stddevs = tf.math.reduce_std(spectogram, 1, keepdims=True)
    spectogram = (spectogram - means) / stddevs + 1e-9
    spectogram = spectogram.numpy()
    spectogram = tf.expand_dims(spectogram, 0)
    return spectogram

def decodeSample(pred):
    input_len = np.ones(pred.shape[0]) * pred.shape[1]
    results = keras.backend.ctc_decode(pred, input_length = input_len, greedy = True)[0][0]
    output_text = []
    for res in results:
        res = tf.strings.reduce_join(itos(res)).numpy().decode("utf-8")
        output_text.append(res)

    return output_text

# Main function
def speech_to_text(model,wavFile):
    model = keras.models.load_model(model)
    spectogram = encodeSample(wavFile)
    pred = model.predict(spectogram)
    return decodeSample(pred)

# Due to trained on less variety audio sample
extracted_text = speech_to_text("/content/Video-Dubbing-with-Lip-Synchronization/Speech to text/speech2text4.keras",extracted_audio_path)

# %%
#@title <h3> Step3.1
import torch
from transformers import AutoModelForSpeechSeq2Seq, AutoProcessor, pipeline
# %%capture
# Comparision with distil-whisper v3 large model
device = "cuda:0" if torch. cuda. is_available() else "cpu"
torch_dtype = torch.float16 if torch. cuda. is_available() else torch.float32

model_id = "distil-whisper/distil-large-v3"
model = AutoModelForSpeechSeq2Seq.from_pretrained(
    model_id, torch_dtype=torch_dtype, use_safetensors=True
)
model.to(device)

processor = AutoProcessor.from_pretrained(model_id)

pipe = pipeline(
    "automatic-speech-recognition",
    model=model,
    tokenizer=processor.tokenizer,
    feature_extractor=processor.feature_extractor,
    max_new_tokens=128,
    torch_dtype=torch_dtype,
    device=device,
)

extracted_text2 = pipe(extracted_audio_path)['text']
clear_output()
print(extracted_text[0])
print(f"extracted text form the audio --> {extracted_text2}")

# %%
#@title <h3>Step4: Lets translate the generated text from the step-3 (right now in hindi)</h1>

# %cd /content/Video-Dubbing-with-Lip-Synchronization/Text Translation/

# !python3 trans_text.py
#%run trans_text.py
from trans_text import generate_trans_text


translated_text = generate_trans_text(extracted_text2)
clear_output()
print(f"Translated Text --> {translated_text}")

# %%
#@title <h3>Step5: Generate the audio from the translated Test</h1>#
#@markdown * Initializing the xTTS-v2 model.\
#@markdown Note:- Give y as input (if asked)
# !pip install TTS gradio==4.5.0 -q
from TTS.api import TTS
import gradio as gr
from IPython.display import Audio
import numpy, pandas
os.environ["COQUI_TOS_AGREED"] = "1"
tts = TTS("tts_models/multilingual/multi-dataset/xtts_v2", gpu=True)
clear_output()
print("xtts-v2 model Loaded Successfully")

# %%
#@title <h3>Step6: Select the Voice model </h1>
import os
import ipywidgets as widgets
from IPython.display import display

selected_voice = ""

# Define the folder path
folder_path = '/content/Video-Dubbing-with-Lip-Synchronization/voice_model'

# Get the list of files in the folder
file_list = os.listdir(folder_path)

# Create a dictionary to store button values (file paths)
button_values = {}

# Create buttons for each file in the folder
buttons = []
for file_name in file_list:
    file_path = os.path.join(folder_path, file_name)
    button = widgets.Button(description=file_name[:file_name.index(".")])
    button_values[button] = file_path  # Store button value (file path) in the dictionary
    buttons.append(button)

# Function to handle button clicks
def on_button_click(button):
    global selected_voice
    selected_voice = button.description
    print(f"You selected the voice of '{button.description}'")
    # print(f"Selected voice file path: {selected_voice}")

    # You can use selected_voice in other functions here or perform further actions

# Assign the on_click event to the buttons
for button in buttons:
    button.on_click(on_button_click)

# Display the buttons
display(*buttons)

# %%
def generate_speech(text, speaker_wav, language):
    # Generate speech using the provided text, speaker voice, and language
    name = speaker_wav
    path = "/content/Video-Dubbing-with-Lip-Synchronization/voice_model/"
    speaker_wav = path + speaker_wav + ".mp3"
    #print(f"speaker_wav = {speaker_wav}")
    if os.path.exists('/content/TTS_output'):
      os.system('rm -r /content/TTS_output')
    os.mkdir("/content/TTS_output")
    file_path = f"/content/TTS_output/{name}_generated.wav"
    tts.tts_to_file(text=text,
                    file_path=file_path,
                    speaker_wav=speaker_wav,
                    language=language)
    return file_path

# %%
#translated_text = "मुझे हिंदू धर्मग्रंथ भगवद गीता की पंक्ति याद है"

# %%
import librosa
length = 9999
gen_speech = ""
for i in range(4): # Iterate two pick smallest length audio sample
  speech = generate_speech(translated_text, selected_voice, "hi")
  #display(Audio(speech, autoplay=False))
  if librosa.get_duration(path=speech) < length:
    gen_speech = speech
display(Audio(gen_speech, autoplay=False))
clear_output()

# %%
#@title <h3> Step7: Generating final output
#@markdown Step-7.1: Preporocessing the muted video for the Wav2lip model </b>
from base64 import b64encode
import moviepy.editor as mp

def showVideo(file_path):
    """Function to display video in Colab"""
    mp4 = open(file_path,'rb').read()
    data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
    display(HTML("""
    <video controls width=600>
        <source src="%s" type="video/mp4">
    </video>
    """ % data_url))

def get_video_resolution(video_path):
    """Function to get the resolution of a video"""
    import cv2
    video = cv2.VideoCapture(video_path)
    width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
    return (width, height)

def resize_video(video_path, new_resolution):
    """Function to resize a video"""
    import cv2
    video = cv2.VideoCapture(video_path)
    fourcc = int(video.get(cv2.CAP_PROP_FOURCC))
    fps = video.get(cv2.CAP_PROP_FPS)
    width, height = new_resolution
    output_path = os.path.splitext(video_path)[0] + '_720p.mp4'
    writer = cv2.VideoWriter(output_path, fourcc, fps, (width, height))
    while True:
        success, frame = video.read()
        if not success:
            break
        resized_frame = cv2.resize(frame, new_resolution)
        writer.write(resized_frame)
    video.release()
    writer.release()

PATH_TO_YOUR_VIDEO = muted_video_path

video_duration = mp.VideoFileClip(PATH_TO_YOUR_VIDEO).duration
if video_duration > 60:
    print("WARNING: Video duration exceeds 60 seconds. Please upload a shorter video.")
    raise SystemExit(0)

video_resolution = get_video_resolution(PATH_TO_YOUR_VIDEO)
print(f"Video resolution: {video_resolution}")
if video_resolution[0] >= 1920 or video_resolution[1] >= 1080:
    print("Resizing video to 720p...")
    os.system(f"ffmpeg -i {PATH_TO_YOUR_VIDEO} -vf scale=1280:720 /content/sample_data/input_vid.wav")
    PATH_TO_YOUR_VIDEO = "/content/sample_data/input_vid.wav"
    print("Video resized to 720p")
    print("Muted Video")
    showVideo(PATH_TO_YOUR_VIDEO)

else:
    print("No resizing needed")
    print("Muted Video")
    showVideo(PATH_TO_YOUR_VIDEO)
    shutil.copyfile(PATH_TO_YOUR_VIDEO, "/content/sample_data/input_vid.wav")

# %%
#@title Step7.2: Preprocessing the generated audio
import os
from IPython.display import Audio
from IPython.core.display import display

upload_method = 'Upload'
# gen_speech
tts_output = "/content/TTS_output"


def displayAudio(audio_path):
  display(Audio(audio_path))


PATH_TO_YOUR_AUDIO = gen_speech

# Load audio with specified sampling rate
import librosa
audio, sr = librosa.load(PATH_TO_YOUR_AUDIO, sr=None)

# Save audio with specified sampling rate
import soundfile as sf
sf.write('/content/sample_data/input_audio.wav', audio, sr, format='wav')

clear_output()






def increase_audio_speed(input_file, output_file, speed_multiplier):
    """
    Increase the speed of an audio WAV file.

    Args:
    - input_file (str): Path to the input WAV file.
    - output_file (str): Path to save the modified audio WAV file.
    - speed_multiplier (float): Factor by which to increase the speed of the audio.

    Returns:
    - None
    """
    # Load the WAV file
    audio = AudioSegment.from_wav(input_file)
    # Increase the speed
    audio_with_increased_speed = audio.speedup(playback_speed=speed_multiplier)
    # Save the modified audio to a new WAV file
    audio_with_increased_speed.export(output_file, format="wav")

# Example usage:
input_file = '/content/sample_data/input_audio.wav'
output_file = '/content/sample_data/input_audio1.wav'
speed_multiplier = librosa.get_duration(path=gen_speech) // librosa.get_duration(path=extracted_audio_path)
if speed_multiplier >1:
  speed_multiplier = 1.4
else:
  speed_multiplier = 1

increase_audio_speed(input_file, output_file, speed_multiplier)
displayAudio(output_file)

# %%
#@title Step7.3: Generating the final output after getting input from the last two steps
# %cd /content/Wav2Lip

# Set up paths and variables for the output file
output_file_path = '/content/Wav2Lip/results/result_voice.mp4'

# Delete existing output file before processing, if any
if os.path.exists(output_file_path):
    os.remove(output_file_path)

pad_top =  0
pad_bottom =  10
pad_left =  0
pad_right =  0
rescaleFactor =  1
nosmooth = True

use_hd_model = True
checkpoint_path = 'checkpoints/wav2lip.pth' if not use_hd_model else 'checkpoints/wav2lip_gan.pth'

if nosmooth == False:
  # !python inference.py --checkpoint_path $checkpoint_path --face "../sample_data/input_vid.wav" --audio "../sample_data/input_audio1.wav" --pads $pad_top $pad_bottom $pad_left $pad_right --resize_factor $rescaleFactor
else:
  # !python inference.py --checkpoint_path $checkpoint_path --face "../sample_data/input_vid.wav" --audio "../sample_data/input_audio1.wav" --pads $pad_top $pad_bottom $pad_left $pad_right --resize_factor $rescaleFactor --nosmooth

#Preview output video
if os.path.exists(output_file_path):
    clear_output()
    print("Final Video Preview")
    print("Download this video from", output_file_path)
    showVideo(output_file_path)

else:
    print("Processing failed. Output video not found.")

# %% [markdown]
# **********************
